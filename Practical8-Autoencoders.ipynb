# %% [markdown]
# **Vanilla Autoencoder**

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from sklearn.datasets import load_digits
from sklearn.preprocessing import StandardScaler

# Load dataset
digits = load_digits()
X = digits.data
X = StandardScaler().fit_transform(X)

# Define the model
input_dim = X.shape[1]
encoding_dim = 32  # Dimensionality of the encoding space

input_layer = Input(shape=(input_dim,))
encoded = Dense(encoding_dim, activation='relu')(input_layer)
decoded = Dense(input_dim, activation='sigmoid')(encoded)

autoencoder_vanilla = Model(input_layer, decoded)
autoencoder_vanilla.compile(optimizer='adam', loss='binary_crossentropy')

# Train the model
autoencoder_vanilla.fit(X, X, epochs=50, batch_size=256, shuffle=True, validation_split=0.2)

# Evaluate the model
encoded_X = autoencoder_vanilla.predict(X)
# Out:
# Epoch 1/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.7529 - val_loss: 0.7075
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6926 - val_loss: 0.6593
# Epoch 3/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6422 - val_loss: 0.6129
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5825 - val_loss: 0.5665
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5282 - val_loss: 0.5193
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4745 - val_loss: 0.4704
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4237 - val_loss: 0.4196
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3657 - val_loss: 0.3660
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3008 - val_loss: 0.3092
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2392 - val_loss: 0.2495
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1681 - val_loss: 0.1867
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1028 - val_loss: 0.1208
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0240 - val_loss: 0.0517
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: -0.0578 - val_loss: -0.0203
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: -0.1323 - val_loss: -0.0954
# Epoch 16/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: -0.2134 - val_loss: -0.1733
# Epoch 17/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: -0.3114 - val_loss: -0.2554
# Epoch 18/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: -0.3734 - val_loss: -0.3404
# Epoch 19/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: -0.4886 - val_loss: -0.4294
# Epoch 20/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: -0.5807 - val_loss: -0.5227
# Epoch 21/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: -0.6793 - val_loss: -0.6204
# Epoch 22/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: -0.7851 - val_loss: -0.7221
# Epoch 23/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: -0.9031 - val_loss: -0.8294
# Epoch 24/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: -1.0459 - val_loss: -0.9413
# Epoch 25/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: -1.1950 - val_loss: -1.0590
# Epoch 26/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: -1.2913 - val_loss: -1.1816
# Epoch 27/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: -1.4380 - val_loss: -1.3106
# Epoch 28/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: -1.5970 - val_loss: -1.4452
# Epoch 29/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: -1.7200 - val_loss: -1.5861
# Epoch 30/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: -1.8618 - val_loss: -1.7340
# Epoch 31/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: -2.0383 - val_loss: -1.8885
# Epoch 32/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: -2.2344 - val_loss: -2.0505
# Epoch 33/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: -2.4028 - val_loss: -2.2185
# Epoch 34/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: -2.6242 - val_loss: -2.3949
# Epoch 35/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: -2.8349 - val_loss: -2.5767
# Epoch 36/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: -3.0151 - val_loss: -2.7663
# Epoch 37/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: -3.3019 - val_loss: -2.9648
# Epoch 38/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: -3.4066 - val_loss: -3.1688
# Epoch 39/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: -3.7319 - val_loss: -3.3816
# Epoch 40/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: -3.8615 - val_loss: -3.5999
# Epoch 41/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: -4.0671 - val_loss: -3.8285
# Epoch 42/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: -4.4474 - val_loss: -4.0641
# Epoch 43/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: -4.7575 - val_loss: -4.3086
# Epoch 44/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: -4.9679 - val_loss: -4.5596
# Epoch 45/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: -5.2029 - val_loss: -4.8184
# Epoch 46/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: -5.4402 - val_loss: -5.0861
# Epoch 47/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: -5.9192 - val_loss: -5.3634
# Epoch 48/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: -6.1873 - val_loss: -5.6472
# Epoch 49/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: -6.2943 - val_loss: -5.9393
# Epoch 50/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: -6.8843 - val_loss: -6.2404
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %% [markdown]
# **Deep Autoencoder**

# %%
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model

# Define the model
input_layer = Input(shape=(input_dim,))
encoded = Dense(128, activation='relu')(input_layer)
encoded = Dense(64, activation='relu')(encoded)
encoded = Dense(32, activation='relu')(encoded)

decoded = Dense(64, activation='relu')(encoded)
decoded = Dense(128, activation='relu')(decoded)
decoded = Dense(input_dim, activation='sigmoid')(decoded)

autoencoder_deep = Model(input_layer, decoded)
autoencoder_deep.compile(optimizer='adam', loss='binary_crossentropy')

# Train the model
autoencoder_deep.fit(X, X, epochs=50, batch_size=256, shuffle=True, validation_split=0.2)

# Evaluate the model
encoded_X_deep = autoencoder_deep.predict(X)
# Out:
# Epoch 1/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - loss: 0.6872 - val_loss: 0.6395
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.6155 - val_loss: 0.5114
# Epoch 3/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4611 - val_loss: 0.2548
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1984 - val_loss: -0.0636
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: -0.1004 - val_loss: -0.4039
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: -0.4623 - val_loss: -1.0020
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: -1.2881 - val_loss: -2.3055
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: -3.0593 - val_loss: -5.2198
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: -6.8316 - val_loss: -11.6273
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: -15.1358 - val_loss: -24.9528
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: -32.5921 - val_loss: -51.8549
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: -66.1090 - val_loss: -104.6164
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: -133.3468 - val_loss: -203.9866
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: -253.4920 - val_loss: -386.7138
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: -470.8910 - val_loss: -710.1784
# Epoch 16/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: -857.4025 - val_loss: -1261.9313
# Epoch 17/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: -1470.8556 - val_loss: -2175.0862
# Epoch 18/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: -2645.8809 - val_loss: -3650.7959
# Epoch 19/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: -4228.7163 - val_loss: -5980.4341
# Epoch 20/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: -6615.3413 - val_loss: -9546.2832
# Epoch 21/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: -10692.2031 - val_loss: -14821.5273
# Epoch 22/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: -16155.2793 - val_loss: -22526.1699
# Epoch 23/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: -25216.7363 - val_loss: -33623.0430
# Epoch 24/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: -38172.3945 - val_loss: -49242.0664
# Epoch 25/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: -54524.7578 - val_loss: -70816.1094
# Epoch 26/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: -77763.3281 - val_loss: -100171.4922
# Epoch 27/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: -105400.5000 - val_loss: -139594.4219
# Epoch 28/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: -142716.7500 - val_loss: -191533.9062
# Epoch 29/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: -209753.8750 - val_loss: -260595.8281
# Epoch 30/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: -284569.8438 - val_loss: -349840.1250
# Epoch 31/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: -367956.3438 - val_loss: -463952.3125
# Epoch 32/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: -499409.9688 - val_loss: -609976.8750
# Epoch 33/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: -611779.3750 - val_loss: -794500.8125
# Epoch 34/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: -848163.5000 - val_loss: -1026989.6875
# Epoch 35/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: -1113035.7500 - val_loss: -1315761.6250
# Epoch 36/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: -1387145.5000 - val_loss: -1668923.7500
# Epoch 37/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: -1798017.1250 - val_loss: -2100301.2500
# Epoch 38/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: -2139186.5000 - val_loss: -2621460.5000
# Epoch 39/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: -2746977.0000 - val_loss: -3252827.0000
# Epoch 40/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: -3359898.5000 - val_loss: -4002716.7500
# Epoch 41/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: -4094214.0000 - val_loss: -4901987.0000
# Epoch 42/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: -4880268.0000 - val_loss: -5964042.5000
# Epoch 43/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: -6199335.5000 - val_loss: -7226029.5000
# Epoch 44/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: -7494042.5000 - val_loss: -8708043.0000
# Epoch 45/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: -9272715.0000 - val_loss: -10433745.0000
# Epoch 46/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: -10855925.0000 - val_loss: -12428298.0000
# Epoch 47/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: -12788629.0000 - val_loss: -14746018.0000
# Epoch 48/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: -15187567.0000 - val_loss: -17427780.0000
# Epoch 49/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: -17154254.0000 - val_loss: -20503790.0000
# Epoch 50/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: -19913634.0000 - val_loss: -24041176.0000
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %% [markdown]
# **Convolutional Autoencoder**

# %%
from tensorflow.keras.layers import Input, Conv2D, Conv2DTranspose, Flatten, Reshape
from tensorflow.keras.models import Model

# Reshape the data to fit the Conv2D input
X_reshaped = X.reshape((X.shape[0], 8, 8, 1))  # Example for 8x8 images

# Define the model
input_layer = Input(shape=(8, 8, 1))
x = Conv2D(32, (3, 3), activation='relu', padding='same')(input_layer)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = Flatten()(x)
x = Dense(32, activation='relu')(x)
x = Dense(64 * 8 * 8, activation='relu')(x)
x = Reshape((8, 8, 64))(x)
x = Conv2DTranspose(32, (3, 3), activation='relu', padding='same')(x)
x = Conv2DTranspose(1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder_convolutional = Model(input_layer, x)
autoencoder_convolutional.compile(optimizer='adam', loss='binary_crossentropy')

# Train the model
autoencoder_convolutional.fit(X_reshaped, X_reshaped, epochs=50, batch_size=256, shuffle=True, validation_split=0.2)

# Evaluate the model
encoded_X_conv = autoencoder_convolutional.predict(X_reshaped)
# Out:
# Epoch 1/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - loss: 0.6573 - val_loss: 0.2696
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step - loss: 0.1557 - val_loss: -0.1413
# Epoch 3/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 174ms/step - loss: -0.1676 - val_loss: -0.8255
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 184ms/step - loss: -1.7261 - val_loss: -3.9949
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 165ms/step - loss: -8.6339 - val_loss: -17.2616
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - loss: -37.3709 - val_loss: -68.3122
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - loss: -129.5040 - val_loss: -236.2848
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - loss: -442.3026 - val_loss: -722.2526
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - loss: -1242.1556 - val_loss: -1989.0178
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - loss: -3186.4089 - val_loss: -4881.7451
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: -7588.9307 - val_loss: -11212.8789
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - loss: -16605.9336 - val_loss: -24502.4590
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: -37900.9023 - val_loss: -50826.2148
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: -71198.9375 - val_loss: -100070.7891
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - loss: -135170.7812 - val_loss: -187761.4844
# Epoch 16/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 177ms/step - loss: -255729.2188 - val_loss: -340666.9688
# Epoch 17/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 184ms/step - loss: -452337.9375 - val_loss: -595916.8125
# Epoch 18/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 188ms/step - loss: -809663.7500 - val_loss: -1008967.9375
# Epoch 19/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: -1301870.5000 - val_loss: -1654057.3750
# Epoch 20/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - loss: -2245355.0000 - val_loss: -2646988.7500
# Epoch 21/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - loss: -3447216.2500 - val_loss: -4119013.2500
# Epoch 22/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - loss: -5440990.5000 - val_loss: -6226487.0000
# Epoch 23/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - loss: -7923546.5000 - val_loss: -9222505.0000
# Epoch 24/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - loss: -11495671.0000 - val_loss: -13424053.0000
# Epoch 25/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - loss: -16530647.0000 - val_loss: -19263790.0000
# Epoch 26/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: -24305992.0000 - val_loss: -27293458.0000
# Epoch 27/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - loss: -32591810.0000 - val_loss: -38093476.0000
# Epoch 28/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: -46533308.0000 - val_loss: -52425732.0000
# Epoch 29/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: -62245752.0000 - val_loss: -71246104.0000
# Epoch 30/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - loss: -85420352.0000 - val_loss: -95665472.0000
# Epoch 31/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - loss: -113193744.0000 - val_loss: -126878336.0000
# Epoch 32/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 180ms/step - loss: -141694912.0000 - val_loss: -166302400.0000
# Epoch 33/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 190ms/step - loss: -184741664.0000 - val_loss: -216071152.0000
# Epoch 34/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 197ms/step - loss: -270662528.0000 - val_loss: -278507840.0000
# Epoch 35/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/step - loss: -318733504.0000 - val_loss: -354758944.0000
# Epoch 36/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - loss: -425463104.0000 - val_loss: -448704192.0000
# Epoch 37/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - loss: -494216768.0000 - val_loss: -562043584.0000
# Epoch 38/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: -649068544.0000 - val_loss: -700341248.0000
# Epoch 39/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - loss: -768841024.0000 - val_loss: -866672256.0000
# Epoch 40/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - loss: -957608192.0000 - val_loss: -1066060672.0000
# Epoch 41/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step - loss: -1218822144.0000 - val_loss: -1304481792.0000
# Epoch 42/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 138ms/step - loss: -1450299136.0000 - val_loss: -1584680448.0000
# Epoch 43/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - loss: -1709928320.0000 - val_loss: -1913189120.0000
# Epoch 44/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - loss: -2267120640.0000 - val_loss: -2302099712.0000
# Epoch 45/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 148ms/step - loss: -2580159744.0000 - val_loss: -2749872640.0000
# Epoch 46/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 233ms/step - loss: -3178106624.0000 - val_loss: -3275619584.0000
# Epoch 47/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 183ms/step - loss: -3786107648.0000 - val_loss: -3883564032.0000
# Epoch 48/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 151ms/step - loss: -4501586432.0000 - val_loss: -4583080960.0000
# Epoch 49/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - loss: -4988010496.0000 - val_loss: -5381845504.0000
# Epoch 50/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: -6094078976.0000 - val_loss: -6302533120.0000
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step

# %% [markdown]
# **Comparing Results**

# %%
# Ensure your input data X has the correct shape
X_reshaped = X.reshape(1797, 8, 8, 1)  # Modify according to the actual shape of your data

# 1. Vanilla Autoencoder
reconstructed_X_vanilla = autoencoder_vanilla.predict(X_reshaped)
mse_vanilla = mean_squared_error(X_reshaped.flatten(), reconstructed_X_vanilla.flatten())
print(f'Vanilla Autoencoder MSE: {mse_vanilla}')

# 2. Deep Autoencoder
reconstructed_X_deep = autoencoder_deep.predict(X_reshaped)
mse_deep = mean_squared_error(X_reshaped.flatten(), reconstructed_X_deep.flatten())
print(f'Deep Autoencoder MSE: {mse_deep}')

# 3. Convolutional Autoencoder
reconstructed_X_conv = autoencoder_convolutional.predict(X_reshaped)
mse_conv = mean_squared_error(X_reshaped.flatten(), reconstructed_X_conv.flatten())
print(f'Convolutional Autoencoder MSE: {mse_conv}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-571995328c0c> in <cell line: 5>()
#       3
#       4 # 1. Vanilla Autoencoder
# ----> 5 reconstructed_X_vanilla = autoencoder_vanilla.predict(X_reshaped)
#       6 mse_vanilla = mean_squared_error(X_reshaped.flatten(), reconstructed_X_vanilla.flatten())
#       7 print(f'Vanilla Autoencoder MSE: {mse_vanilla}')
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# ValueError: as_list() is not defined on an unknown TensorShape.

# %%
print(X.shape)
# Out:
# (1797, 64)
